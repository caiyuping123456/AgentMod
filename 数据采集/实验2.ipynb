# %%
import pandas as pd
df = pd.read_csv('D:\Py_Project\Langcahin\数据采集\data\drinks.csv')
df.loc[df.continent.isnull()].index
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\cai\AppData\Local\Temp\ipykernel_38064\1845548560.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('D:\Py_Project\Langcahin\数据采集\data\drinks.csv')
# Index([  5,  11,  14,  17,  32,  41,  43,  50,  51,  54,  68,  69,  73,  74,
#         84, 109, 122, 130, 143, 144, 145, 174, 184],
#       dtype='int64')

# %%
print(df.head())
# 直接全部替换为’NA’
df = df.fillna('NA')
# 或者在读取数据时加入参数keep_default_na=False
df = pd.read_csv('D:\Py_Project\Langcahin\数据采集\data\drinks.csv', keep_default_na=False)
print(df)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# ...

# %%
df.groupby('continent')[['beer_servings', 'spirit_servings', 'wine_servings']].mean()
print(df)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
print("啤酒最多的国家：",df.iloc[df.beer_servings.argmax(), 0])
print("烈酒最多的国家：",df.iloc[df.spirit_servings.argmax(), 0])
print("红酒最多的国家：",df.iloc[df.wine_servings.argmax(), 0])
# Out:
# 啤酒最多的国家： Namibia
# 烈酒最多的国家： Grenada
# 红酒最多的国家： France
