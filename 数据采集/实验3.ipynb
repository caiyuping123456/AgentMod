# %%
import pandas as pd
df = pd.read_csv('D:\Py_Project\Langcahin\数据采集\data\DOGE-USD.csv')
print(df.dtypes)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\cai\AppData\Local\Temp\ipykernel_20712\4889278.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('D:\Py_Project\Langcahin\数据采集\data\DOGE-USD.csv')
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date)
print(df.dtypes)
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2358 non-null   datetime64[ns]
#  1   Open    2354 non-null   float64
#  2   High    2354 non-null   float64
#  3   Low     2354 non-null   float64
#  4   Close   2354 non-null   float64
#  5   Volume  2354 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 110.7 KB
# None

# %%
df['Date'].loc[df['Open'].isnull()]
df['Date'].loc[df['Close'].isnull()]
df['Date'].loc[df['High'].isnull()]
df['Date'].loc[df['Low'].isnull()]
df['Date'].loc[df['Volume'].isnull()]
df = df.fillna(method='pad')
print(df)
# Out:
#            Date      Open      High       Low     Close        Volume
# 0    2014-09-17  0.000293  0.000299  0.000260  0.000268  1.463600e+06
# 1    2014-09-18  0.000268  0.000325  0.000267  0.000298  2.215910e+06
# 2    2014-09-19  0.000298  0.000307  0.000275  0.000277  8.835630e+05
# 3    2014-09-20  0.000276  0.000310  0.000267  0.000292  9.930040e+05
# 4    2014-09-21  0.000293  0.000299  0.000284  0.000288  5.391400e+05
# ...         ...       ...       ...       ...       ...           ...
# 2353 2021-02-25  0.056615  0.057808  0.049869  0.050167  2.356982e+09
# 2354 2021-02-26  0.050138  0.052472  0.048708  0.050480  1.694323e+09
# 2355 2021-02-27  0.050500  0.051920  0.049297  0.050083  1.286230e+09
# 2356 2021-02-28  0.050097  0.050134  0.045088  0.048052  1.408101e+09
# 2357 2021-03-01  0.049335  0.049403  0.048029  0.048350  1.189262e+09
#
# [2358 rows x 6 columns]
# C:\Users\cai\AppData\Local\Temp\ipykernel_20712\3510914147.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='pad')

# %%
print(df.High.max())
print(df.Low.min())
print(df['Date'].loc[df['High'].argmax()])
print(df['Date'].loc[df['Low'].argmin()])
# Out:
# 0.084945
# 8.5e-05
# 2021-02-08 00:00:00
# 2015-05-07 00:00:00

# %%
import matplotlib.pyplot as plt
plt.plot(df.Date, df.High)

plt.show()  # 如图8-1所示

# %%
import numpy as np

plt.plot(df.Date, np.log10(df.Volume))
plt.show()  # 如图8-2示
